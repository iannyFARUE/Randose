# %% [markdown]
# <a href="https://colab.research.google.com/github/iannyFARUE/Randose/blob/main/RANDose_Runner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/iannyFARUE/Randose.git
# %cd Randose
# Out:
# Cloning into 'Randose'...
# remote: Enumerating objects: 4214, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4214 (delta 0), reused 0 (delta 0), pack-reused 4212 (from 2)
# Receiving objects: 100% (4214/4214), 528.63 MiB | 55.87 MiB/s, done.
# Resolving deltas: 100% (1489/1489), done.
# Updating files: 100% (4066/4066), done.
# /content/Randose

# %%
# !pip install -U uv

# %%
# !uv pip install -e .
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 113 packages in 18ms
# Prepared 13 packages in 15.75s
# Uninstalled 13 packages in 794ms
# Installed 27 packages in 148ms
#  + argparse==1.4.0
#  + bitsandbytes==0.49.2
#  + colt5-attention==0.11.1
#  - cuda-bindings==12.9.5
#  + cuda-bindings==12.9.4
#  - datasets==4.0.0
#  + datasets==4.5.0
#  + einops-exts==0.0.4
#  + einx==0.3.0
#  - huggingface-hub==1.4.0
#  + huggingface-hub==0.36.2
#  + hyper-connections==0.4.9
#  - joblib==1.5.3
#  + joblib==1.3.2
#  + local-attention==1.11.2
#  + loguru==0.7.3
#  - matplotlib==3.10.0
#  + matplotlib==3.10.8
#  - numpy==2.0.2
#  + numpy==2.4.2
#  - nvidia-nvshmem-cu12==3.3.20
#  + nvidia-nvshmem-cu12==3.4.5
#  - pyarrow==18.1.0
#  + pyarrow==23.0.1
#  + pytorch-msssim==1.0.0
#  + randose==0.1.0 (from file:///content/Randose)
#  - scikit-learn==1.6.1
#  + scikit-learn==1.5.2
#  + simpleitk==2.5.3
#  - torch==2.9.0+cu128
#  + torch==2.10.0
#  + torch-einops-utils==0.0.29
# ...

# %%
# !uv run python utils/data.py
# Out:
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Installed 110 packages in 158ms
# ...

# %%
#!rm -r OpenKBP_C3D
# !pip install -U "matplotlib<3.9" matplotlib-inline
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 103.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.8
#     Uninstalling matplotlib-3.10.8:
#       Successfully uninstalled matplotlib-3.10.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# randose 0.1.0 requires matplotlib>=3.10.8, but you have matplotlib 3.8.4 which is incompatible.
# fastai 2.8.6 requires torch<2.10,>=1.10, but you have torch 2.10.0 which is incompatible.
# ...

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA H100 80GB HBM3

# %%
# !python train.py \
    --model Model_MTASP \
    --loss Loss_DC_PTV \
    --batch_size 2 \
    --list_GPU_ids 0 \
    --max_iter 80000 \
    --project_name RANDose_reproduction
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771295537.675754   19489 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771295537.678989   19489 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771295537.687201   19489 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771295537.687216   19489 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771295537.687218   19489 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
3
