# %% [markdown]
# <a href="https://colab.research.google.com/github/iannyFARUE/Randose/blob/main/RANDose_Runner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/iannyFARUE/Randose.git
# %cd Randose
# Out:
# Cloning into 'Randose'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 65 (delta 30), reused 42 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (65/65), 215.86 KiB | 19.62 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# /content/Randose

# %%
# !pip install uv
# Out:
# Collecting uv
#   Downloading uv-0.10.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.10.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.0/23.0 MB 110.6 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.10.2

# %%
# !uv sync
# Out:
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 114 packages in 0.67ms
# Prepared 110 packages in 35.61s
# Installed 110 packages in 217ms
#  + accelerate==1.12.0
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aiosignal==1.4.0
#  + annotated-types==0.7.0
#  + anyio==4.12.1
#  + argparse==1.4.0
#  + attrs==25.4.0
#  + beartype==0.22.9
#  + bitsandbytes==0.49.1
#  + certifi==2026.1.4
#  + charset-normalizer==3.4.4
#  + click==8.3.1
#  + colt5-attention==0.11.1
#  + contourpy==1.3.3
#  + cuda-bindings==12.9.4
#  + cuda-pathfinder==1.3.3
#  + cycler==0.12.1
#  + datasets==4.5.0
#  + dill==0.4.0
#  + einops==0.8.2
#  + einops-exts==0.0.4
#  + einx==0.3.0
#  + filelock==3.20.3
#  + fonttools==4.61.1
#  + frozendict==2.4.7
#  + frozenlist==1.8.0
#  + fsspec==2025.10.0
#  + gitdb==4.0.12
#  + gitpython==3.1.46
#  + h11==0.16.0
#  + hf-xet==1.2.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + huggingface-hub==0.36.2
#  + hyper-connections==0.4.9
#  + idna==3.11
#  + jinja2==3.1.6
#  + joblib==1.3.2
#  + kiwisolver==1.4.9
#  + local-attention==1.11.2
#  + loguru==0.7.3
#  + markdown-it-py==4.0.0
#  + markupsafe==3.0.3
#  + matplotlib==3.10.8
#  + mdurl==0.1.2
#  + mpmath==1.3.0
#  + multidict==6.7.1
#  + multiprocess==0.70.18
#  + networkx==3.6.1
#  + numpy==2.4.2
#  + nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cudnn-cu12==9.10.2.21
#  + nvidia-cufft-cu12==11.3.3.83
#  + nvidia-cufile-cu12==1.13.1.3
#  + nvidia-curand-cu12==10.3.9.90
#  + nvidia-cusolver-cu12==11.7.3.90
#  + nvidia-cusparse-cu12==12.5.8.93
#  + nvidia-cusparselt-cu12==0.7.1
#  + nvidia-nccl-cu12==2.27.5
#  + nvidia-nvjitlink-cu12==12.8.93
#  + nvidia-nvshmem-cu12==3.4.5
#  + nvidia-nvtx-cu12==12.8.90
#  + opencv-python==4.13.0.92
#  + packaging==26.0
#  + pandas==3.0.0
#  + pillow==12.1.1
#  + platformdirs==4.5.1
#  + propcache==0.4.1
#  + protobuf==6.33.5
#  + psutil==7.2.2
#  + pyarrow==23.0.0
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + pygments==2.19.2
#  + pyparsing==3.3.2
#  + python-dateutil==2.9.0.post0
#  + pytorch-msssim==1.0.0
#  + pyyaml==6.0.3
#  + regex==2026.1.15
#  + requests==2.32.5
#  + rich==14.3.2
#  + safetensors==0.7.0
#  + scikit-learn==1.5.2
#  + scipy==1.17.0
#  + sentry-sdk==2.52.0
#  + setuptools==82.0.0
#  + simpleitk==2.5.3
#  + six==1.17.0
#  + smmap==5.0.2
#  + sympy==1.14.0
#  + threadpoolctl==3.6.0
#  + tokenizers==0.22.2
#  + torch==2.10.0
#  + torch-einops-utils==0.0.28
#  + torchvision==0.25.0
#  + tqdm==4.67.3
#  + transformers==4.57.6
#  + triton==3.6.0
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + urllib3==2.6.3
#  + vector-quantize-pytorch==1.27.20
#  + wandb==0.24.2
#  + xxhash==3.6.0
#  + yarl==1.22.0
#  + zetascale==2.8.8

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA H100 80GB HBM3

# %%
# !uv run python train.py \
    --model Model_MTASP \
    --loss Loss_DC_PTV \
    --batch_size 2 \
    --list_GPU_ids 0 \
    --max_iter 80000 \
    --project_name RANDose_reproduction
# Out:
# Traceback (most recent call last):
#   File "/content/Randose/train.py", line 12, in <module>
#     from models.mt import *
#   File "/content/Randose/models/mt.py", line 9, in <module>
#     from utils.blocks import *
#   File "/content/Randose/utils/blocks.py", line 9, in <module>
#     from zeta.utils import exists
#   File "/content/Randose/.venv/lib/python3.12/site-packages/zeta/__init__.py", line 6, in <module>
#     from zeta.models import *  # noqa: F403, E402
#     ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Randose/.venv/lib/python3.12/site-packages/zeta/models/__init__.py", line 3, in <module>
#     from zeta.models.andromeda import Andromeda
#   File "/content/Randose/.venv/lib/python3.12/site-packages/zeta/models/andromeda.py", line 4, in <module>
#     from zeta.structs.transformer import Decoder, Transformer
#   File "/content/Randose/.venv/lib/python3.12/site-packages/zeta/structs/__init__.py", line 4, in <module>
#     from zeta.structs.local_transformer import LocalTransformer
#   File "/content/Randose/.venv/lib/python3.12/site-packages/zeta/structs/local_transformer.py", line 6, in <module>
#     from zeta.nn.attention.local_attention_mha import LocalMHA
#   File "/content/Randose/.venv/lib/python3.12/site-packages/zeta/nn/__init__.py", line 3, in <module>
#     from zeta.nn.attention import *  # noqa: F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Randose/.venv/lib/python3.12/site-packages/zeta/nn/attention/__init__.py", line 11, in <module>
#     from zeta.nn.attention.mixture_attention import (
#   File "/content/Randose/.venv/lib/python3.12/site-packages/zeta/nn/attention/mixture_attention.py", line 13, in <module>
#     from zeta.nn.modules.rms_norm import RMSNorm
#   File "/content/Randose/.venv/lib/python3.12/site-packages/zeta/nn/modules/__init__.py", line 65, in <module>
#     from zeta.nn.modules.flow_matching import (
#   File "/content/Randose/.venv/lib/python3.12/site-packages/zeta/nn/modules/flow_matching.py", line 6, in <module>
#     import matplotlib.pyplot as plt
#   File "/content/Randose/.venv/lib/python3.12/site-packages/matplotlib/__init__.py", line 1299, in <module>
#     rcParams['backend'] = os.environ.get('MPLBACKEND')
#     ~~~~~~~~^^^^^^^^^^^
#   File "/content/Randose/.venv/lib/python3.12/site-packages/matplotlib/__init__.py", line 774, in __setitem__
#     raise ValueError(f"Key {key}: {ve}") from None
# ValueError: Key backend: 'module://matplotlib_inline.backend_inline' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']
